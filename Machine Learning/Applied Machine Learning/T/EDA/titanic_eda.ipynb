# %% [markdown]
# ### Question 1
#
# Load the Titanic dataset and display:
# - Dataset shape
# - First 10 rows
# - 5 random samples

# %%
import pandas as pd

df = pd.read_csv("titanic_data_updated.csv")

print("Shape: ",df.shape)
print("------------------------------")
print("First 10 Rows:")
display(df.head(10))
print("------------------------------")
print("Sample:")
display(df.sample(5))
# Out:
# Shape:  (891, 12)
# ------------------------------
# First 10 Rows:
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C
# ------------------------------
# Sample:
#      PassengerId Survived Pclass                             Name     Sex  \
# 690          691      yes  first          Dick, Mr. Albert Adrian    male
# 649          650      yes  third  Stanley, Miss. Amy Zillah Elsie  female
# 642          643       no  third    Skoog, Miss. Margit Elizabeth  female
# 22            23      yes  third      McGowan, Miss. Anna "Annie"  female
# 680          681       no  third              Peters, Miss. Katie  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 690  31.0      1      0     17474  57.0000   B20        S
# 649  23.0      0      0  CA. 2314   7.5500   NaN        S
# 642   2.0      3      2    347088  27.9000   NaN        S
# 22   15.0      0      0    330923   8.0292   NaN        Q
# 680   NaN      0      0    330935   8.1375   NaN        Q

# %% [markdown]
# ### Question 2
#
# Perform feature screening on the Titanic dataset by:
# - Finding total missing values
# - Finding duplicate rows
# - Removing duplicate rows permanently

# %%
print(f"Total Missing Values: {df.isnull().sum()}")
print("------------------------------")
print(f"Total duplicate Rows: {df.duplicated().sum()}")
print("------------------------------")
df.drop_duplicates()
# Out:
# Total Missing Values: PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ------------------------------
# Total duplicate Rows: 0
# ------------------------------
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Question 3
#
# Perform statistical profiling of the Titanic dataset and display:
# - Dataset information
# - Statistical summary of numerical columns
# - Also write 2 observations from the output.

# %%
print("Dataset Information: ")
print(df.info())
print("------------------------------")
print("Statistical Summary of Numerical Columns: ")
print(df.describe())
print("------------------------------")
print("Two Observations: \n")
print("From dataset information, we can see there are total 891 rows and 12 columns in the dataset and there are both categorical and numerical data in the dataset.\nFrom the statistical summary, we see the average age of all people is 29.69, and maximum age is 80 years and minimum is less then 1 year (0.42 year).")
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB
# None
# ------------------------------
# Statistical Summary of Numerical Columns:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200
# ------------------------------
# Two Observations:
#
# From dataset information, we can see there are total 891 rows and 12 columns in the dataset and there are both categorical and numerical data in the dataset.
# From the statistical summary, we see the average age of all people is 29.69, and maximum age is 80 years and minimum is less then 1 year (0.42 year).

# %% [markdown]
# ### Question 4
#
# Perform univariate categorical analysis on the Survived column by:
#
# - Creating a countplot
#
# - Calculating percentage distribution
#
# - Creating a pie chart
#
# - Write 2 insights from the analysis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data=df, x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
print("Parcentage Distribution: ")
(df['Survived'].value_counts()/len(df))*100
# Out:
# Parcentage Distribution:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
plt.title("Pie Chart of Survival Rate")
survived_count = df['Survived'].value_counts()
survived_label = df['Survived'].unique()

plt.pie(survived_count, labels=survived_label,autopct="%1.1f%%")
plt.show()

# %%
print("2 Insights from the analysis: ")
print("Around 550 people couldn't survive, whereas slightly less then 350 people survibed.\nThe survival rate is 38.4%.")
# Out:
# 2 Insights from the analysis:
# Around 550 people couldn't survive, whereas slightly less then 350 people survibed.
# The survival rate is 38.4%.

# %% [markdown]
# ### Question 5
#
# Perform univariate numerical analysis on the Age column by:
# - Creating a histogram
# - Creating a KDE plot
# - Write 2 observations from the plots.

# %%
plt.title("Histogram of Age")
sns.histplot(data=df,x='Age')
# Out:
# <Axes: title={'center': 'Histogram of Age'}, xlabel='Age', ylabel='Count'>

# %%
plt.title("Probability Density of Age")
sns.kdeplot(data=df,x='Age')
# Out:
# <Axes: title={'center': 'Probability Density of Age'}, xlabel='Age', ylabel='Density'>

# %%
print("2 obervations from the plot:\n")
print("A large number of people were in between 20 and 35, where most of them are around 25.\nSome people with age more than 70 were in the ship as well.")
# Out:
# 2 obervations from the plot:
#
# A large number of people were in between 20 and 35, where most of them are around 25.
# Some people with age more than 70 were in the ship as well.

# %% [markdown]
# ### Question 6
#
# - Perform multivariate analysis between Sex and Survived using a countplot with hue.
# - Also calculate normalized survival ratios using groupby().
# - Write 2 insights from the analysis.

# %%
plt.title("Survival count based on 'Sex'")

sns.countplot(data=df,x='Survived',hue='Sex')
# Out:
# <Axes: title={'center': "Survival count based on 'Sex'"}, xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### Question 7
#
# - Create a barplot showing the relationship between Pclass and Fare.
# - Write 2 observations from the visualization.

# %%
sns.barplot(data=df, x='Pclass',y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
print("2 insights: ")
print("""The amount of fare were pretty high for the 'First Class' passengers than the other two classes, exceeding $80 with some exceptionally higher amount as well.\nThe fare for 2nd class was around $20, and for 3rd class, it was less than $20""")
# Out:
# 2 insights:
# The amount of fare were pretty high for the 'First Class' passengers than the other two classes, exceeding $80 with some exceptionally higher amount as well.
# The fare for 2nd class was around $20, and for 3rd class, it was less than $20

# %% [markdown]
# ### Question 8
# - Create a KDE plot to compare the Age distribution of survived and non-survived passengers.
# - Write 2 insights from the graph.

# %%
sns.kdeplot(data=df,x='Age',hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Question 9
#
# Perform feature engineering and train-test split by:
# - Dropping PassengerId, Name, and Ticket columns
# - Separating features (X) and target (y)
# - Splitting the dataset using test_size=0.2 and random_state=42
# - Display the shapes of train and test datasets.

# %% [markdown]
# ### Question 10
#
# Handle missing values in the Titanic dataset by:
# - Imputing missing Age values using SimpleImputer with mean strategy
# - Imputing missing Embarked values using most frequent strategy
# - Imputing missing Cabin values using constant strategy with "Missing"
# - Finally, check whether any missing values remain.
