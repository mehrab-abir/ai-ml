# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 693         0       3    male  25.0      0      0    7.2250        C  Third
# 534         0       3  female  30.0      0      0    8.6625        S  Third
# 184         1       3  female   4.0      0      2   22.0250        S  Third
# 527         0       1    male   NaN      0      0  221.7792        S  First
# 785         0       3    male  25.0      0      0    7.2500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 693    man        True  NaN    Cherbourg    no   True
# 534  woman       False  NaN  Southampton    no   True
# 184  child       False  NaN  Southampton   yes  False
# 527    man        True    C  Southampton    no   True
# 785    man        True  NaN  Southampton    no   True

# %%
from ydata_profiling import ProfileReport

data_profile = ProfileReport(df,title='Titanic Data Profile')

data_profile.to_file("titanic_data_profile.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2
#       3 data_profile = ProfileReport(df,title='Titanic Data Profile')
#       4
#
# File c:\Users\mehra\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\mehra\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
# ...
