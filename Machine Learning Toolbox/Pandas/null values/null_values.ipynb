# %%
import pandas as pd

df = pd.read_csv('../student_data.csv')
df.sample(3)
# Out:
#    StudentID        FullName  Data Structure Marks  Algorithm Marks  \
# 6     PH1007  Mahmudul Hasan                  80.0             80.0
# 19    PH1020      Nasir Khan                  86.0             86.0
# 17    PH1018     Babul Ahmed                  88.0             88.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor Location
# 6            NaN      In Progress     2024-04-01  Mr. Karim    Dhaka
# 19          89.0        Completed     2025-10-02  Ms. Salma    Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma   Sylhet

# %% [markdown]
# unique() counts 'Nan'

# %%
df['Python Marks'].unique()
# Out:
# array([88., nan, 85., 82., 95., 78., 76., 91., 87., 79., 84., 93., 89.])

# %%
len(df['Python Marks'].unique())
# Out:
# 13

# %% [markdown]
# nunique() does not count 'Nan'

# %%
df['Python Marks'].nunique()
# Out:
# 12

# %% [markdown]
# nunique() can work on entire dataframe

# %%
df.nunique()
# Out:
# StudentID               20
# FullName                20
# Data Structure Marks    12
# Algorithm Marks         12
# Python Marks            12
# CompletionStatus         3
# EnrollmentDate          20
# Instructor               3
# Location                 5
# dtype: int64

# %%
df.isnull() # True if null, False otherwise
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df['Python Marks'].isnull() # True -> if null, False otherwise
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Python Marks, dtype: bool

# %% [markdown]
# notnull()...opposite of isnull()</br>
# If null,--> False, otherwise True

# %%
df['Python Marks'].notnull()
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14     True
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Python Marks, dtype: bool

# %%
df['Python Marks'].hasnans # Output: True, because Nan exists
# Out:
# True

# %%
df['StudentID'].hasnans # not null values here
# Out:
# False
