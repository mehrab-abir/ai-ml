# %%
import pandas as pd

stdf = pd.read_csv('student_data.csv')
stdf.sample(3)
# Out:
#    StudentID        FullName  Data Structure Marks  Algorithm Marks  \
# 6     PH1007  Mahmudul Hasan                  80.0             80.0
# 7     PH1008     Nadia Islam                  81.0             81.0
# 13    PH1014      Urmi Akter                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 6            NaN      In Progress     2024-04-01  Mr. Karim       Dhaka
# 7           85.0        Completed     2024-04-22  Ms. Salma  Chattogram
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi

# %%
import pandas as pd

data = {
    "Name": [
        "Jhon Doe", "David Ross", "Sarah Chen", "Mike Ross", "Emily White",
        "Liam O'Connor", "Sofia Rodriguez", "Aisha Khan", "Emily White",
        "Daniela Gomez", "Elena Petrova", "Jack Harrison"
    ],
    "City": [
        "North York", "New York", "Toronto", "Toronto", "London",
        "Dublin", "Madrid", "Dubai", "Tokyo",
        "Madrid", "Berlin", "Sydney"
    ],
    "Country": [
        "Canada", "US", "Canada", "Canada", "UK",
        "Ireland", "Spain", "UAE", "Ireland",
        'Spain', "Germany", "Australia"
    ],
    "Job Title": [
        "Software Engineer", "Backend Developer", "Data Scientist", "Project Manager", "UX Designer",
        "DevOps Engineer", "Frontend Developer", "Product Manager", "Systems Architect",
        "Data Analyst", "Security Engineer", "QA Engineer"
    ],
    "Salary": [
        160000, 155000, 145000, 130000, 120000,
        140000, 115000, 170000, 180000,
        95000, 135000, 110000
    ]
}

df = pd.DataFrame(data)
# Out:
#                Name        City    Country           Job Title  Salary
# 0          Jhon Doe  North York     Canada   Software Engineer  160000
# 1        David Ross    New York         US   Backend Developer  155000
# 2        Sarah Chen     Toronto     Canada      Data Scientist  145000
# 3         Mike Ross     Toronto     Canada     Project Manager  130000
# 4       Emily White      London         UK         UX Designer  120000
# 5     Liam O'Connor      Dublin    Ireland     DevOps Engineer  140000
# 6   Sofia Rodriguez      Madrid      Spain  Frontend Developer  115000
# 7        Aisha Khan       Dubai        UAE     Product Manager  170000
# 8       Emily White       Tokyo    Ireland   Systems Architect  180000
# 9     Daniela Gomez      Madrid      Spain        Data Analyst   95000
# 10    Elena Petrova      Berlin    Germany   Security Engineer  135000
# 11    Jack Harrison      Sydney  Australia         QA Engineer  110000

# %%
df['Salary'].sum()
# Out:
# np.int64(1655000)

# %%
df['Salary'].mean()
# Out:
# np.float64(137916.66666666666)

# %%
df['Salary'].median()
# Out:
# np.float64(137500.0)

# %%
df['Salary'].min()
# Out:
# np.int64(95000)

# %%
df['Salary'].max()
# Out:
# np.int64(180000)

# %% [markdown]
# Standard Deviation

# %%
df['Salary'].std()
# Out:
# np.float64(25535.92241007427)

# %% [markdown]
# Summation of "Data Structure, Python and Algorithm Marks" - using column index

# %%
stdf['Total Marks'] = stdf.iloc[:,2:5].sum(axis=1)
stdf.sample(3)
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016  Ziaur Rahman                  94.0             94.0
# 5     PH1006   Laila Begum                  75.0             75.0
# 13    PH1014    Urmi Akter                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 5           78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi
#
#     Total Marks
# 15        188.0
# 5         228.0
# 13          0.0

# %% [markdown]
# summation of different columns - row-wise

# %%
stdf[['Data Structure Marks','Python Marks']].sum()
# total Data Structure Marks of all students combined
# total Python Marks of all students combined
# Out:
# Data Structure Marks    1344.0
# Python Marks            1285.0
# dtype: float64

# %% [markdown]
# correlation between two columns values

# %%
stdf[['Data Structure Marks','Python Marks']].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.893455
# Python Marks                      0.893455      1.000000

# %% [markdown]
# Standard Deviation

# %%
stdf['Python Marks'].std()
# Out:
# np.float64(5.394000194219323)
