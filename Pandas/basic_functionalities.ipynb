# %%
import pandas as pd

df = pd.read_csv('student_data.csv') 
# print(df)

# df # --> can be view just by writing 'df' instead of 'print(df)'
# Out:
# Index(['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks',
#        'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor',
#        'Location'],
#       dtype='str')

# %%
# some data from the beginning
# df.head()  # default 5
# df.head(10)

# some data from ending
# df.tail() # default 5
# df.tail(2)

# get some sample randomly 
# df.sample(7)

# %%
# information about the data
# df.info()

# some statistical information from nemerical data
# df.describe()

# %%
# see all columns
df.columns

# converting to list
print(list(df.columns))
# Out:
# ['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks', 'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor', 'Location']
